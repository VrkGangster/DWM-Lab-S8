# %%
import numpy as np
import pandas as pd
def input():
  inp={
      'Outlook':['Rain','Rain','Rain','Sunny','Sunny','Rain','Rain','Overcast','Overcast','Sunny','Overcast','Rain','Overcast','Rain'],
      'Temperature':['Cold','Cold','Cold','Cold','Cold','Mild','Hot','Hot','Cold','Hot','Mild','Cold','Hot','Hot'],
      'Humidity':['High','Low','High','High','Normal','Low','Low','Low','High','High','Low','Normal','Normal','Normal'],
      'Wind':['Strong','Strong','Weak','Strong','Weak','Weak','Strong','Weak','Strong','Strong','Weak','Strong','Strong','Weak'],
      'Play Tennis':['No','Yes','No','No','Yes','Yes','Yes','Yes','No','No','Yes','No','No','Yes']
  }
  df=pd.DataFrame(inp)
  c1=0
  c2=0
  for i, r in df.iterrows():
    if r['Play Tennis']=='Yes':
      c1+=1
    else:
      c2+=1
  print('By Outlook')
  o1=0
  o2=0
  count1=0
  #dfout=pd.DataFrame(columns=['Outlook','Count-Play','Count-NoPlay','P-Play','P-NoPlay'])
  for i,r in df.iterrows():
    if r['Outlook']=='Rain':
      count1+=1
      if r['Play Tennis']=='Yes':
        o1+=1
      else:
        o2+=1
  print('Rain',o1,o2,o1/count1,o2/count1)
  o3=0
  o4=0
  count2=0
  for i,r in df.iterrows():
    if r['Outlook']=='Sunny':
      count2+=1
      if r['Play Tennis']=='Yes':
        o3+=1
      else:
        o4+=1
  print('Sunny',o3,o4,o3/count2,o4/count2)
  o5=0
  o6=0
  count3=0
  for i,r in df.iterrows():
    if r['Outlook']=='Overcast':
      count3+=1
      if r['Play Tennis']=='Yes':
        o5+=1
      else:
        o6+=1
  print('Overcast',o5,o6,o5/count3,o6/count3)
  print('By Temperature')
  t1=0
  t2=0
  count4=0
  for i,r in df.iterrows():
    if r['Temperature']=='Hot':
      count4+=1
      if r['Play Tennis']=='Yes':
        t1+=1
      else:
        t2+=1
  print('Hot',t1,t2,t1/count4,t2/count4)
  t3=0
  t4=0
  count5=0
  for i,r in df.iterrows():
    if r['Temperature']=='Mild':
      count5+=1
      if r['Play Tennis']=='Yes':
        t3+=1
      else:
        t4+=1
  print('Mild',t3,t4,t3/count5,t4/count5)
  t5=0
  t6=0
  count6=0
  for i,r in df.iterrows():
    if r['Temperature']=='Cold':
      count6+=1
      if r['Play Tennis']=='Yes':
        t5+=1
      else:
        t6+=1
  print('Cold',t5,t6,t5/count6,t6/count6)
  print('By Humidity')
  h1=0
  h2=0
  count7=0
  for i,r in df.iterrows():
    if r['Humidity']=='High':
      count7+=1
      if r['Play Tennis']=='Yes':
        h1+=1
      else:
        h2+=1
  print('High',h1,h2,h1/count7,h2/count7)
  h3=0
  h4=0
  count8=0
  for i,r in df.iterrows():
    if r['Humidity']=='Low':
      count8+=1
      if r['Play Tennis']=='Yes':
        h3+=1
      else:
        h4+=1
  print('Low',h3,h4,h3/count8,h4/count8)
  h5=0
  h6=0
  count9=0
  for i,r in df.iterrows():
    if r['Humidity']=='Normal':
      count9+=1
      if r['Play Tennis']=='Yes':
        h5+=1
      else:
        h6+=1
  print('Normal',h5,h6,h5/count9,h6/count9)
  print('By Wind')
  w1=0
  w2=0
  count10=0
  for i,r in df.iterrows():
    if r['Wind']=='Strong':
      count10+=1
      if r['Play Tennis']=='Yes':
        w1+=1
      else:
        w2+=1
  print('Strong',w1,w2,w1/count10,w2/count10)
  w3=0
  w4=0
  count11=0
  for i,r in df.iterrows():
    if r['Wind']=='Weak':
      count11+=1
      if r['Play Tennis']=='Yes':
        w3+=1
      else:
        w4+=1
  print('Weak',w3,w4,w3/count11,w4/count11)
  
    
input()
# Out:
# By Outlook
# Rain 4 3 0.5714285714285714 0.42857142857142855
# Sunny 1 2 0.3333333333333333 0.6666666666666666
# Overcast 2 2 0.5 0.5
# By Temperature
# Hot 3 2 0.6 0.4
# Mild 2 0 1.0 0.0
# Cold 2 5 0.2857142857142857 0.7142857142857143
# By Humidity
# High 0 5 0.0 1.0
# Low 5 0 1.0 0.0
# Normal 2 2 0.5 0.5
# By Wind
# Strong 2 6 0.25 0.75
# Weak 5 1 0.8333333333333334 0.16666666666666666
